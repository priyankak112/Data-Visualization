# %% [markdown]
# ## 1. Central Tendency - Mean, Median, Mode

# %%
import numpy as np
from scipy import stats

data = [10, 15, 15, 20, 25]

mean_val = np.mode(data) #np.mode() not available
median_val = np.mean(data) #wrong variable assignment
mode_val = stats.median(data) #incorrect function use

print("Mean:", mean_val)
print("Median:", median_val)
print("Mode:", mode_val)

# %%
#Answer:
import numpy as np
from scipy import stats

data = [10, 15, 15, 20, 25]

mean_val = np.mean(data)
median_val = np.median(data)
mode_val = stats.mode(data).mode

print("Mean:", mean_val)
print("Median:", median_val)
print("Mode:", mode_val)
# Out:
# Mean: 17.0
# Median: 15.0
# Mode: 15

# %% [markdown]
# ## 2. Percentile Calculation

# %%
import numpy as np

data = [10, 20, 30, 40, 50]

percentile_90 = np.percentile(data, 120)#90 th percentile is given as 120
print("90th Percentile:", percentile_90)

# %%
import numpy as np

data = [10, 20, 30, 40, 50]

percentile_90 = np.percentile(data, 90)
print("90th Percentile:", percentile_90)
# Out:
# 90th Percentile: 46.0

# %% [markdown]
# ## 3. Outlier Detection using IQR

# %%
import numpy as np

data = [10, 12, 14, 16, 18, 100]

Q1, Q3 = np.percentile(data, 0.25, 0.75) #no float value here and square bracket needed
IQR = Q3 - Q1 
outliers = [x for x in data if x < (Q1 - 1.5 * IQR) or x > (Q3 + 1.5 * IQR)]

print("Outliers:", outliers)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       1 import numpy as np
#       3 data = [10, 12, 14, 16, 18, 100]
# ----> 5 Q1, Q3 = np.percentile(data, 0.25, 0.75)
#       6 IQR = Q3 - Q1
#       7 outliers = [x for x in data if x < (Q1 - 1.5 * IQR) or x > (Q3 + 1.5 * IQR)]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\numpy\lib\_function_base_impl.py:4273, in percentile(a, q, axis, out, overwrite_input, method, keepdims, weights, interpolation)
#    4270     if np.any(weights < 0):
#    4271         raise ValueError("Weights must be non-negative.")
# -> 4273 return _quantile_unchecked(
#    4274     a, q, axis, out, overwrite_input, method, keepdims, weights)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\numpy\lib\_function_base_impl.py:4550, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims, weights)
#    4541 def _quantile_unchecked(a,
#    4542                         q,
#    4543                         axis=None,
#    (...)   4547                         keepdims=False,
#    4548                         weights=None):
#    4549     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4550     return _ureduce(a,
#    4551                     func=_quantile_ureduce_func,
#    4552                     q=q,
#    4553                     weights=weights,
#    4554                     keepdims=keepdims,
#    4555                     axis=axis,
#    4556                     out=out,
#    4557                     overwrite_input=overwrite_input,
#    4558                     method=method)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\numpy\lib\_function_base_impl.py:3869, in _ureduce(a, func, keepdims, **kwargs)
#    3867 nd = a.ndim
#    3868 if axis is not None:
# -> 3869     axis = _nx.normalize_axis_tuple(axis, nd)
#    3871     if keepdims:
#    3872         if out is not None:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\numpy\_core\numeric.py:1435, in normalize_axis_tuple(axis, ndim, argname, allow_duplicate)
#    1433         pass
#    1434 # Going via an iterator directly is slower than via list comprehension.
# -> 1435 axis = tuple([normalize_axis_index(ax, ndim, argname) for ax in axis])
#    1436 if not allow_duplicate and len(set(axis)) != len(axis):
#    1437     if argname:
#
# TypeError: 'float' object is not iterable

# %%
import numpy as np

data = [10, 12, 14, 16, 18, 100]

Q1, Q3 = np.percentile(data,[25,75])
IQR = Q3 - Q1
outliers = [x for x in data if x < (Q1 - 1.5 * IQR) or x > (Q3 + 1.5 * IQR)]

print("Outliers:", outliers)
# Out:
# Outliers: [100]

# %% [markdown]
# ## 4. Standard Deviation Calculation

# %%
import numpy as np

data = [10, 20, 30, 40, 50]

std_dev = np.std(data, unbiased=True) #unbaised not needed

print("Standard Deviation:", std_dev)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       1 import numpy as np
#       3 data = [10, 20, 30, 40, 50]
# ----> 5 std_dev = np.std(data, unbiased=True)
#       7 print("Standard Deviation:", std_dev)
#
# TypeError: std() got an unexpected keyword argument 'unbiased'

# %%
import numpy as np

data = [10, 20, 30, 40, 50]

std_dev = np.std(data,ddof=1) #Degree of freedom=1 for sample std,dof=0 for population std.

print("Standard Deviation:", std_dev)
# Out:
# Standard Deviation: 14.142135623730951

# %% [markdown]
# ## 5. Hypothesis Testing using T-Test

# %%
from scipy import stats

medication_group = [110, 115, 108, 102, 107]
placebo_group = [120, 125, 130, 122, 128]

t_stat, p_value = stats.ttest_ind(medication_group, placebo_group, axis=1) #axis=1 not valid here

print("T-Statistic:", t_stat)
print("P-Value:", p_value)

# %%
from scipy import stats

medication_group = [110, 115, 108, 102, 107]
placebo_group = [120, 125, 130, 122, 128]

t_stat, p_value = stats.ttest_ind(medication_group, placebo_group)

print("T-Statistic:", t_stat)
print("P-Value:", p_value)
# Out:
# T-Statistic: -5.921023912553299
# P-Value: 0.0003532844625064416

# %% [markdown]
# ## 6.Multicollinearity Detection Using VIF

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor

data = pd.DataFrame({
    'Age': [5, 3, 8, 2, 1, 7, 4, 6, 3, 9],
    'Mileage': [50000, 30000, 80000, 20000, 15000, 70000, 40000, 60000, 35000, 90000],
    'EngineSize': [1.2, 1.6, 2.0, 1.0, 1.3, 2.5, 1.8, 2.2, 1.5, 2.8]
})

vif_data = pd.DataFrame()
vif_data['Feature'] = data.columns
vif_data['VIF'] = [variance_inflation_factor(data.values, i) for i in range(data.shape[1], -1)]

print(vif_data)

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor

data = pd.DataFrame({
    'Age': [5, 3, 8, 2, 1, 7, 4, 6, 3, 9],
    'Mileage': [50000, 30000, 80000, 20000, 15000, 70000, 40000, 60000, 35000, 90000],
    'EngineSize': [1.2, 1.6, 2.0, 1.0, 1.3, 2.5, 1.8, 2.2, 1.5, 2.8]
})

vif_data = pd.DataFrame()
vif_data['Feature'] = data.columns
vif_data['VIF'] = [variance_inflation_factor(data.values, i) for i in range(data.shape[1])]

print(vif_data)
# Out:
#    Age  Mileage  EngineSize
# 0    5    50000         1.2
# 1    3    30000         1.6
# 2    8    80000         2.0
# 3    2    20000         1.0
# 4    1    15000         1.3
# 5    7    70000         2.5
# 6    4    40000         1.8
# 7    6    60000         2.2
# 8    3    35000         1.5
# 9    9    90000         2.8
#       Feature          VIF
# 0         Age   885.531249
# 1     Mileage  1059.299089
# 2  EngineSize    22.929372
